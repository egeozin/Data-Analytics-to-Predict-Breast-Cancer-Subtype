# %%
import numpy as np
import pandas as pd
from IPython.core.display import display, HTML

# %%
def merge_dataframes(data_frames, index_col='PATIENT_ID'):
    dfs = []
    for data in data_frames:
        data = pd.read_csv(data)
        data.set_index(index_col, inplace=True)
        display(data.head())
        # TODO: Make sample_id the index 
        dfs.append(data)
    
    result = pd.concat(dfs, axis=1)
    
    return result

# %%
data_frames = ['imputed_patient_clean_with_therapies_1.csv', 'imputed_sample_clean_1.csv']

# %%
merge_dataframes(data_frames)
# Out:
#                      Unnamed: 0  ABEMACICLIB  ANASTROZOLE  BEVACIZUMAB  \
# PATIENT_ID
# MBCProject_kAFQF3t6           1            0            0            0
# MBCProject_7XFmtytw           2            0            0            0
# MBCProject_K7f6fdUz           3            0            0            0
# MBCProject_bvHXCoTY           4            0            0            0
# MBCProject_VrsMsqTb           5            0            0            0
#
#                      CAPECITABINE  CARBOPLATIN  CISPLATIN  CYCLOPHOSPHAMIDE  \
# PATIENT_ID
# MBCProject_kAFQF3t6             0            1          0                 0
# MBCProject_7XFmtytw             0            0          0                 0
# MBCProject_K7f6fdUz             0            0          0                 0
# MBCProject_bvHXCoTY             0            0          0                 0
# MBCProject_VrsMsqTb             0            0          0                 0
#
# ...
